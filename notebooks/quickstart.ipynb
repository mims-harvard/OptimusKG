# %% [markdown]
# # OptimusKG JupyterLab Quickstart

# %% [markdown]
# This is a simple quickstart of OptimusKG inside JupyterLab. We recommend you to also read the [Kedro documentation for JupyterLab]((https://docs.kedro.org/en/stable/notebooks_and_ipython/kedro_and_notebooks.html))

# %% [markdown]
# ## Useful injected variables

# %%
CATALOG = catalog
print(f"There are {len(CATALOG.keys())} registered datasets in the catalog")
# Out:
# There are 110 registered datasets in the catalog

# %%
CONTEXT = context
print(f"OptimusKG project path is '{CONTEXT.project_path}'")
# Out:
# OptimusKG project path is '/home/viti/Documents/repos/harvard/optimuskg'

# %%
PIPELINES = pipelines
DEFAULT_PIPELINE = PIPELINES.get(
    "__default__"
)  # get default pipeline (the one that runs with uv run kedro run)
DEFAULT_PIPELINE.grouped_nodes_by_namespace.keys()  # get pipeline namespaces (should be bronze, silver, gold)
# Out:
# [05/11/25 22:50:22] WARNING  /home/viti/Documents/repos/harvard/optimuskg/.venv/lib/python3.12/site ]8;id=661521;file:///usr/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=7451;file:///usr/lib/python3.12/warnings.py#110\110]8;;\
#                              -packages/kedro/framework/project/__init__.py:356: UserWarning:
#                              Expected the 'create_pipeline' function in the
#                              'optimuskg.pipelines.gold' module to return a 'Pipeline' object, got
#                              'NoneType' instead. Nothing defined therein will be returned by
#                              'find_pipelines'.
#                                warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# dict_keys(['bronze', 'silver'])

# %% [markdown]
# ## Loading data from the silver layer

# %%
import re

# %%
landing_ds_names = CATALOG.filter(name_regex=re.compile("^landing"))

# %%
sorted(landing_ds_names)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'landing.bgee.homo_sapiens_expressions_advanced',
#     'landing.ctd.ctd_exposure_events',
#     'landing.drugbank.carrier',
#     'landing.drugbank.enzyme',
#     'landing.drugbank.full_database',
#     'landing.drugbank.gene_map',
#     'landing.drugbank.target',
#     'landing.drugbank.transporter',
#     'landing.drugbank.vocabulary',
#     'landing.drugcentral.psql_dump',
#     'landing.gene_names.gene_names',
#     'landing.ncbigene.gene2go',
#     'landing.ontology.biolink',
#     'landing.ontology.disease',
#     'landing.ontology.gene',
#     'landing.ontology.human_phenotype',
#     'landing.ontology.mondo',
#     'landing.ontology.orphanet',
#     'landing.ontology.uber_anatomy',
#     'landing.opentargets.disease_to_phenotype',
#     'landing.opentargets.diseases',
#     'landing.opentargets.drug_mappings',
# ...

# %%
for ds_name in landing_ds_names:
    ds = CATALOG.load(ds_name)
    print(data.head(3))
# Out:
# [05/11/25 22:59:45] INFO     Loading data from landing.drugbank.full_database             ]8;id=165221;file:///home/viti/Documents/repos/harvard/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/kedro_data_catalog.py\kedro_data_catalog.py]8;;\:]8;id=192155;file:///home/viti/Documents/repos/harvard/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/kedro_data_catalog.py#757\757]8;;\
#                              (LXMLDataset)...
# shape: (3, 3)
# ┌──────────────┬────────────┬────────────────────┐
# │ ncbi_gene_id ┆ go_term_id ┆ go_term_type       │
# │ ---          ┆ ---        ┆ ---                │
# │ i64          ┆ i64        ┆ str                │
# ╞══════════════╪════════════╪════════════════════╡
# │ 1            ┆ 2764       ┆ biological_process │
# │ 1            ┆ 5576       ┆ cellular_component │
# │ 1            ┆ 5615       ┆ cellular_component │
# └──────────────┴────────────┴────────────────────┘
# ...
