# %% [markdown]
# # OptimusKG JupyterLab Quickstart

# %%
import re
import polars as pl

# %% [markdown]
# ## Adapting silver layer to Biocypher nodes and edges

# %%
ds_names = catalog.filter(name_regex=re.compile("^bronze"))

# %%
sorted(ds_names)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'bronze.bgee.gene_expressions_in_anatomy',
#     'bronze.ctd.ctd_exposure_events',
#     'bronze.disgenet.disgenet_diseases',
#     'bronze.disgenet.disgenet_phenotypes',
#     'bronze.drug_drug',
#     'bronze.drug_protein',
#     'bronze.drugbank.vocabulary',
#     'bronze.drug_disease',
#     'bronze.gene_names.protein_names',
#     'bronze.ncbigene.protein_go_associations',
#     'bronze.onsides.high_confidence',
#     'bronze.ontology.go_relations',
#     'bronze.ontology.go_terms',
#     'bronze.ontology.hpo_mappings',
#     'bronze.ontology.mondo_relations',
#     'bronze.ontology.mondo_terms',
#     'bronze.ontology.mondo_xrefs',
#     'bronze.ontology.phenotypes',
#     'bronze.ontology.phenotypes_parents',
#     'bronze.ontology.phenotypes_xrefs',
#     'bronze.ontology.uberon_relations',
#     'bronze.ontology.uberon_terms',
#     'bronze.opentargets.disease_phenotype_ids',
#     'bronze.opentargets.disease_to_phenotype',
#     'bronze.opentargets.diseases',
#     'bronze.opentargets.drug_mappings',
#     'bronze.opentargets.evidence.cancer_gene_census',
#     'bronze.opentargets.evidence.chembl',
#     'bronze.opentargets.evidence.clingen',
#     'bronze.opentargets.evidence.crispr',
#     'bronze.opentargets.evidence.crispr_screen',
#     'bronze.opentargets.evidence.expression_atlas',
#     'bronze.opentargets.evidence.gene2phenotype',
#     'bronze.opentargets.evidence.gene_burden',
#     'bronze.opentargets.evidence.genomics_england',
#     'bronze.opentargets.evidence.intogen',
#     'bronze.opentargets.evidence.orphanet',
#     'bronze.opentargets.evidence.progeny',
#     'bronze.opentargets.evidence.reactome',
#     'bronze.opentargets.evidence.slapenrich',
#     'bronze.opentargets.evidence.sysbio',
#     'bronze.opentargets.evidence.uniprot_literature',
#     'bronze.opentargets.mondo_efo_mappings',
#     'bronze.opentargets.targets',
#     'bronze.reactome.reactome_ncbi',
#     'bronze.reactome.reactome_relations',
#     'bronze.reactome.reactome_terms',
#     'bronze.umls.mrconso'
# ]

# %%
catalog.load("silver.bgee.anatomy_protein").head(10)
# Out:
# [07/14/25 00:28:16] INFO     Loading data from silver.bgee.anatomy_protein                ]8;id=363185;file:///home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/kedro_data_catalog.py\kedro_data_catalog.py]8;;\:]8;id=225291;file:///home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/kedro_data_catalog.py#757\757]8;;\
#                              (CSVDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shape: (10, 12)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬──────────┐
# │ call_quali ┆ expression ┆ relation  ┆ relation_ ┆ … ┆ y_id      ┆ y_type  ┆ y_name    ┆ y_source │
# │ ty         ┆ _rank      ┆ ---       ┆ type      ┆   ┆ ---       ┆ ---     ┆ ---       ┆ ---      │
# │ ---        ┆ ---        ┆ str       ┆ ---       ┆   ┆ str       ┆ str     ┆ str       ┆ str      │
# │ str        ┆ str        ┆           ┆ str       ┆   ┆           ┆         ┆           ┆          │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪══════════╡
# │ gold       ┆ 4950.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ uterine   ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00002     ┆         ┆ cervix    ┆          │
# │ gold       ┆ 6880.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ islet of  ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00006     ┆         ┆ Langerhan ┆          │
# │            ┆            ┆           ┆           ┆   ┆           ┆         ┆ s         ┆          │
# │ gold       ┆ 3090.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ pituitary ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00007     ┆         ┆ gland     ┆          │
# │ gold       ┆ 9420.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ zone of   ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00014     ┆         ┆ skin      ┆          │
# │ gold       ┆ 12700.0    ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ lymph     ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00029     ┆         ┆ node      ┆          │
# │ gold       ┆ 4920.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ tendon    ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00043     ┆         ┆           ┆          │
# │ gold       ┆ 6240.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ dorsal    ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00044     ┆         ┆ root      ┆          │
# │            ┆            ┆           ┆           ┆   ┆           ┆         ┆ ganglion  ┆          │
# │ gold       ┆ 2760.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ urethra   ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00057     ┆         ┆           ┆          │
# │ gold       ┆ 5210.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ large     ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00059     ┆         ┆ intestine ┆          │
# │ gold       ┆ 3820.0     ┆ anatomy_p ┆ expressio ┆ … ┆ UBERON:00 ┆ anatomy ┆ renal glo ┆ BGEE     │
# │ quality    ┆            ┆ rotein    ┆ n present ┆   ┆ 00074     ┆         ┆ merulus   ┆          │
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴─────────┴───────────┴──────────┘
