# %%
catalog.load("silver.nodes.gene").unnest("properties").filter(
    (pl.col("id").str.contains("ENSG00000163513"))
).write_json("gene_df.json")
# Out:
# [03/01/26 01:18:54] INFO     Loading data from silver.nodes.gene (ParquetDataset)...           ]8;id=591517;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=497403;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
catalog.load("silver.nodes.phenotype").unnest("properties").filter(
    (pl.col("id").str.contains("HP_0000023"))
).head().write_json("phenotype.json")
# Out:
# [02/28/26 17:00:15] INFO     Loading data from silver.nodes.phenotype (ParquetDataset)...      ]8;id=214274;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=264793;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
import polars as pl

# %%
catalog.load("silver.edges.phenotype_protein") \
    .unnest("properties") \
    .filter(
        (pl.col("from").str.contains("HP_0000023")) &
        (pl.col("disease_specificity_index").is_not_null())
        # (pl.col("to").str.contains("ENSG00000000003"))
    ).write_json("edge.json")
# Out:
# [02/28/26 18:36:39] INFO     Loading data from silver.edges.phenotype_protein                  ]8;id=509207;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=933496;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                              (ParquetDataset)...
