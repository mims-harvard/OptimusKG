# %% [markdown]
# # OptimusKG JupyterLab Quickstart

# %% [markdown]
# This is a simple quickstart of OptimusKG inside JupyterLab. We recommend you to also read the [Kedro documentation for JupyterLab]((https://docs.kedro.org/en/stable/notebooks_and_ipython/kedro_and_notebooks.html))

# %%
import re
import polars as pl
from ydata_profiling import ProfileReport
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>

# %% [markdown]
# ## Useful injected variables

# %%
CATALOG = catalog
print(f"There are {len(CATALOG.keys())} registered datasets in the catalog")
# Out:
# There are 114 registered datasets in the catalog

# %%
CONTEXT = context
print(f"OptimusKG project path is '{CONTEXT.project_path}'")
# Out:
# OptimusKG project path is '/home/viti/Documents/repos/personal/hardvard/optimuskg'

# %%
PIPELINES = pipelines
DEFAULT_PIPELINE = PIPELINES.get(
    "__default__"
)  # get default pipeline (the one that runs with uv run kedro run)
DEFAULT_PIPELINE.grouped_nodes_by_namespace.keys()  # get pipeline namespaces (should be bronze, silver, gold)
# Out:
#                     WARNING  /home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/pytho ]8;id=143804;file:///usr/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=294736;file:///usr/lib/python3.12/warnings.py#110\110]8;;\
#                              n3.12/site-packages/kedro/framework/project/__init__.py:356:
#                              UserWarning: Expected the 'create_pipeline' function in the
#                              'optimuskg.pipelines.gold' module to return a 'Pipeline' object, got
#                              'NoneType' instead. Nothing defined therein will be returned by
#                              'find_pipelines'.
#                                warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# dict_keys(['bronze', 'silver'])

# %% [markdown]
# ## Adapting silver layer to Biocypher nodes and edges

# %%
ds_names = CATALOG.filter(name_regex=re.compile("^silver"))

# %%
sorted(ds_names)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'silver.bgee.gene_expressions_in_anatomy',
#     'silver.ctd.ctd_exposure_exposure_interactions',
#     'silver.ctd.ctd_exposure_protein_interactions',
#     'silver.drugbank.drug_drug',
#     'silver.drugbank.drug_protein',
#     'silver.drugcentral.drug_disease',
#     'silver.ncbigene.protein_biological_process_interactions',
#     'silver.ncbigene.protein_cellular_component_interactions',
#     'silver.ncbigene.protein_molecular_function_interactions',
#     'silver.opentargets.disease_to_phenotype',
#     'silver.opentargets.evidence.cancer_gene_census',
#     'silver.opentargets.evidence.chembl_drug_disease',
#     'silver.opentargets.evidence.chembl_drug_gene',
#     'silver.opentargets.evidence.clingen',
#     'silver.opentargets.evidence.crispr',
#     'silver.opentargets.evidence.crispr_screen',
#     'silver.opentargets.evidence.expression_atlas',
#     'silver.opentargets.evidence.gene2phenotype',
#     'silver.opentargets.evidence.gene_burden',
#     'silver.opentargets.evidence.genomics_england',
#     'silver.opentargets.evidence.intogen',
#     'silver.opentargets.evidence.orphanet',
#     'silver.opentargets.evidence.progeny',
#     'silver.opentargets.evidence.reactome',
#     'silver.opentargets.evidence.slapenrich',
#     'silver.opentargets.evidence.sysbio',
#     'silver.opentargets.evidence.uniprot_literature',
#     'silver.opentargets.opentargets_edges',
#     'silver.reactome.pathway_pathway_interactions',
#     'silver.reactome.pathway_protein_interactions'
# ]

# %%
## BGE

# %%
df_bgee = CATALOG.load("silver.reactome.pathway_pathway_interactions")
df_bgee.head(100)
# Out:
# [05/16/25 03:25:14] INFO     Loading data from                                            ]8;id=493870;file:///home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/kedro_data_catalog.py\kedro_data_catalog.py]8;;\:]8;id=202400;file:///home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/python3.12/site-packages/kedro/io/kedro_data_catalog.py#757\757]8;;\
#                              silver.reactome.pathway_pathway_interactions (CSVDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shape: (100, 10)
# ┌────────────┬────────────┬────────────┬─────────┬───┬────────────┬─────────┬───────────┬──────────┐
# │ relation   ┆ display_re ┆ x_id       ┆ x_type  ┆ … ┆ y_id       ┆ y_type  ┆ y_name    ┆ y_source │
# │ ---        ┆ lation     ┆ ---        ┆ ---     ┆   ┆ ---        ┆ ---     ┆ ---       ┆ ---      │
# │ str        ┆ ---        ┆ str        ┆ str     ┆   ┆ str        ┆ str     ┆ str       ┆ str      │
# │            ┆ str        ┆            ┆         ┆   ┆            ┆         ┆           ┆          │
# ╞════════════╪════════════╪════════════╪═════════╪═══╪════════════╪═════════╪═══════════╪══════════╡
# │ pathway_pa ┆ parent-chi ┆ R-HSA-3642 ┆ pathway ┆ … ┆ R-HSA-3645 ┆ pathway ┆ Loss of   ┆ REACTOME │
# │ thway      ┆ ld         ┆ 278        ┆         ┆   ┆ 790        ┆         ┆ Function  ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ of TGFBR2 ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ in …      ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-1643 ┆ pathway ┆ … ┆ R-HSA-9675 ┆ pathway ┆ Disease   ┆ REACTOME │
# │ thway      ┆ ld         ┆ 685        ┆         ┆   ┆ 132        ┆         ┆           ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-5619 ┆ pathway ┆ … ┆ R-HSA-5619 ┆ pathway ┆ SLC trans ┆ REACTOME │
# │ thway      ┆ ld         ┆ 102        ┆         ┆   ┆ 098        ┆         ┆ porter    ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ disorders ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-6887 ┆ pathway ┆ … ┆ R-HSA-2500 ┆ pathway ┆ Mitotic   ┆ REACTOME │
# │ thway      ┆ ld         ┆ 7          ┆         ┆   ┆ 257        ┆         ┆ Prometaph ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ ase       ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-9675 ┆ pathway ┆ … ┆ R-HSA-5423 ┆ pathway ┆ Diseases  ┆ REACTOME │
# │ thway      ┆ ld         ┆ 135        ┆         ┆   ┆ 599        ┆         ┆ of DNA    ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ repair    ┆          │
# │ …          ┆ …          ┆ …          ┆ …       ┆ … ┆ …          ┆ …       ┆ …         ┆ …        │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-8979 ┆ pathway ┆ … ┆ R-HSA-1635 ┆ pathway ┆ Triglycer ┆ REACTOME │
# │ thway      ┆ ld         ┆ 227        ┆         ┆   ┆ 60         ┆         ┆ ide metab ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ olism     ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-6806 ┆ pathway ┆ … ┆ R-HSA-6806 ┆ pathway ┆ Signaling ┆ REACTOME │
# │ thway      ┆ ld         ┆ 834        ┆         ┆   ┆ 942        ┆         ┆ by MET    ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-1741 ┆ pathway ┆ … ┆ R-HSA-1768 ┆ pathway ┆ APC/C-med ┆ REACTOME │
# │ thway      ┆ ld         ┆ 43         ┆         ┆   ┆ 14         ┆         ┆ iated deg ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ radation  ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ of …      ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-2027 ┆ pathway ┆ … ┆ R-HSA-2109 ┆ pathway ┆ Cell      ┆ REACTOME │
# │ thway      ┆ ld         ┆ 33         ┆         ┆   ┆ 93         ┆         ┆ surface   ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ interacti ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ ons at t… ┆          │
# │ pathway_pa ┆ parent-chi ┆ R-HSA-1226 ┆ pathway ┆ … ┆ R-HSA-5655 ┆ pathway ┆ Signaling ┆ REACTOME │
# │ thway      ┆ ld         ┆ 099        ┆         ┆   ┆ 253        ┆         ┆ by FGFR   ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ in        ┆          │
# │            ┆            ┆            ┆         ┆   ┆            ┆         ┆ disease   ┆          │
# └────────────┴────────────┴────────────┴─────────┴───┴────────────┴─────────┴───────────┴──────────┘

# %%
ProfileReport(df_bgee.to_pandas(), title="Profiling Report")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# IOStream.flush timed out
#
#   0%|                                                                                                                                                                                         | 0/10 [00:00<?, ?it/s]
#  10%|█████████████████▋                                                                                                                                                               | 1/10 [00:19<02:49, 18.84s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:19<00:00,  1.91s/it]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# <class 'ydata_profiling.profile_report.ProfileReport'>.__repr__ returned empty string
