# %%
OPTIMUSKG_CATALOG = catalog
print(f"There are {len(OPTIMUSKG_CATALOG.keys())} registered datasets in the catalog")

# %%
OPTIMUSKG_CONTEXT = context
print(f"OptimusKG project path is '{OPTIMUSKG_CONTEXT.project_path}'")

# %%
OPTIMUSKG_PIPELINES = pipelines
default_pipeline = OPTIMUSKG_PIPELINES.get(
    "__default__"
)  # get default pipeline (the one that runs with uv run kedro run)
default_pipeline.grouped_nodes_by_namespace.keys()  # get pipeline namespaces (should be bronze, silver, gold)
