# %% [markdown]
# # OptimusKG JupyterLab Quickstart

# %%
import re
import polars as pl

# %% [markdown]
# ## Adapting silver layer to Biocypher nodes and edges

# %%
ds_names = catalog.filter(name_regex=re.compile("^bronze"))

# %%
sorted(ds_names)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'bronze.bgee.gene_expressions_in_anatomy',
#     'bronze.ctd.ctd_exposure_events',
#     'bronze.disgenet.diseases',
#     'bronze.disgenet.disgenet_phenotypes',
#     'bronze.drug_disease',
#     'bronze.drug_drug',
#     'bronze.drug_protein',
#     'bronze.drugbank.vocabulary',
#     'bronze.gene_names.protein_names',
#     'bronze.onsides.high_confidence',
#     'bronze.ontology.go_relations',
#     'bronze.ontology.go_terms',
#     'bronze.ontology.hp_relations',
#     'bronze.ontology.hp_terms',
#     'bronze.ontology.hp_xrefs',
#     'bronze.ontology.mondo_relations',
#     'bronze.ontology.mondo_terms',
#     'bronze.ontology.mondo_xrefs',
#     'bronze.ontology.uberon_relations',
#     'bronze.ontology.uberon_terms',
#     'bronze.opentargets.disease',
#     'bronze.opentargets.disease_phenotype',
# ...

# %%
catalog.load("silver.edges.anatomy_protein").unnest("properties").head(10)
# Out:
# [08/28/25 23:28:24] INFO     Loading data from silver.edges.anatomy_protein               ]8;id=425797;file:///home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/kedro_data_catalog.py\kedro_data_catalog.py]8;;\:]8;id=8577;file:///home/viti/Documents/repos/personal/hardvard/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/kedro_data_catalog.py#757\757]8;;\
#                              (ParquetDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shape: (10, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ from       ┆ to         ┆ relation   ┆ undirecte ┆ relationT ┆ expressio ┆ callQuali ┆ sources   │
# │ ---        ┆ ---        ┆ ---        ┆ d         ┆ ype       ┆ nRank     ┆ ty        ┆ ---       │
# ...
