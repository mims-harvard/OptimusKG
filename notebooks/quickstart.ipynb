# %%
# Get df names given the URI in the catalog using regular expressions
silver_nodes = catalog.filter(name_regex="silver.nodes") # get list of nodes in silver layer, you can get the edges by using "silver.edges"
silver_nodes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'silver.nodes.anatomy',
#     'silver.nodes.gene',
#     'silver.nodes.disease',
#     'silver.nodes.exposure',
#     'silver.nodes.biological_process',
#     'silver.nodes.molecular_function',
#     'silver.nodes.pathway',
#     'silver.nodes.phenotype',
#     'silver.nodes.cellular_component',
#     'silver.nodes.drug'
# ]

# %%
silver_nodes_dfs = [catalog.load(df_name) for df_name in silver_nodes]
# Out:
# [12/15/25 16:05:59] INFO     Loading data from silver.nodes.anatomy (ParquetDataset)...        ]8;id=950416;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=437070;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from silver.nodes.gene (ParquetDataset)...           ]8;id=932974;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=802445;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# [12/15/25 16:06:00] INFO     Loading data from silver.nodes.disease (ParquetDataset)...        ]8;id=250688;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=739232;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from silver.nodes.exposure (ParquetDataset)...       ]8;id=503061;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=63940;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from silver.nodes.biological_process                 ]8;id=297786;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=450214;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                              (ParquetDataset)...
#                     INFO     Loading data from silver.nodes.molecular_function                 ]8;id=18267;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=228706;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                              (ParquetDataset)...
#                     INFO     Loading data from silver.nodes.pathway (ParquetDataset)...        ]8;id=448724;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=686176;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from silver.nodes.phenotype (ParquetDataset)...      ]8;id=59715;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=719636;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from silver.nodes.cellular_component                 ]8;id=363863;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=274678;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                              (ParquetDataset)...
#                     INFO     Loading data from silver.nodes.drug (ParquetDataset)...           ]8;id=125521;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=293224;file:///home/viti/Documents/repos/optimuskg/.venv/lib/python3.13/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
silver_nodes_dfs[0].head() # get first df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shape: (5, 3)
# ┌────────────────┬───────────┬─────────────────────────────────┐
# │ id             ┆ node_type ┆ properties                      │
# │ ---            ┆ ---       ┆ ---                             │
# │ str            ┆ str       ┆ struct[9]                       │
# ╞════════════════╪═══════════╪═════════════════════════════════╡
# │ UBERON_0000000 ┆ anatomy   ┆ {"UBERON","processual entity",… │
# │ UBERON_0000002 ┆ anatomy   ┆ {"UBERON","uterine cervix","Lo… │
# │ UBERON_0000003 ┆ anatomy   ┆ {"UBERON","naris","Orifice of … │
# │ UBERON_0000004 ┆ anatomy   ┆ {"UBERON","nose","The olfactor… │
# │ UBERON_0000005 ┆ anatomy   ┆ {"UBERON","chemosensory organ"… │
# └────────────────┴───────────┴─────────────────────────────────┘
